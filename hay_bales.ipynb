# %% [markdown]
# <a href="https://colab.research.google.com/github/Tomasprr/hay-bales/blob/main/hay_bales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="IbdSBLFXp4gUcTPrdbIL")
project = rf.workspace("tim-play-9cqdp").project("hay-k69yv")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install ultralytics

from ultralytics import YOLO

# 1. Cargamos un modelo pre-entrenado "Nano" (yolov8n.pt)
# Usamos el Nano porque es el más rápido para aprender y el que mejor irá luego en tu dron.
model = YOLO('yolov8n.pt')

# 2. Entrenamos el modelo
# data: ruta al archivo data.yaml
# epochs: cuántas veces la IA verá todo el dataset (empieza con 50)
# imgsz: tamaño de la imagen (640 es el estándar equilibrado)
results = model.train(data='hay-1/data.yaml', epochs=50, imgsz=640, plots=True)
# Out:
# Ultralytics 8.4.42 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
